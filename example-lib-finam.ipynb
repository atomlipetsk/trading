# %%
import import_ipynb
from lib.finam import get_period
import pandas

data = get_period("01.01.2019", "02.01.2019", "EURUSD")

print(data[0])
# Out:
# importing Jupyter notebook from /home/jovyan/work/ikudinov/lib/finam.ipynb
#     <TICKER>  <PER>    <DATE>  <TIME>   <OPEN>   <HIGH>    <LOW>  <CLOSE>  \
# 0     EURUSD      1  20190101     100  1.14560  1.14572  1.14550  1.14561
# 1     EURUSD      1  20190101     200  1.14561  1.14572  1.14550  1.14565
# 2     EURUSD      1  20190101     300  1.14565  1.14570  1.14550  1.14570
# 3     EURUSD      1  20190101     400  1.14570  1.14572  1.14560  1.14571
# 4     EURUSD      1  20190101     500  1.14570  1.14574  1.14563  1.14571
# 5     EURUSD      1  20190101     600  1.14571  1.14576  1.14563  1.14573
# 6     EURUSD      1  20190101     700  1.14573  1.14574  1.14567  1.14572
# 7     EURUSD      1  20190101     800  1.14572  1.14575  1.14565  1.14571
# 8     EURUSD      1  20190101     900  1.14571  1.14576  1.14566  1.14575
# 9     EURUSD      1  20190101    1000  1.14575  1.14580  1.14568  1.14575
# 10    EURUSD      1  20190101    1100  1.14576  1.14585  1.14560  1.14581
# ...
